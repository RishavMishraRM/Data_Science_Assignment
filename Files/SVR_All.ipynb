# %%
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.to_csv("housepricedata.csv",index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
X=data.drop(["price"],axis=1)

# %%
X
# Out:
#                id             date  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000         3       1.00         1180
# 1      6414100192  20141209T000000         3       2.25         2570
# 2      5631500400  20150225T000000         2       1.00          770
# 3      2487200875  20141209T000000         4       3.00         1960
# 4      1954400510  20150218T000000         3       2.00         1680
# ...           ...              ...       ...        ...          ...
# 21608   263000018  20140521T000000         3       2.50         1530
# 21609  6600060120  20150223T000000         4       2.50         2310
# 21610  1523300141  20140623T000000         2       0.75         1020
# 21611   291310100  20150116T000000         3       2.50         1600
# 21612  1523300157  20141015T000000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %%
y=data.price

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
X.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
# ...

# %%
X=X.drop(["id","date"],axis=1)

# %%
X
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
# ...

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)

# %%
X_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 20102         4       2.50         2990      6037     2.0           0     0
# 2735          4       2.75         2710     45963     2.0           0     0
# 11469         4       1.50         1620      5444     1.5           0     0
# 477           3       1.50         1050      4590     1.0           0     0
# 4366          3       2.50         1750      3900     2.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 16059         5       2.75         2500      7140     1.0           0     0
# 2798          4       2.50         1930      7014     2.0           0     0
# 11531         4       2.50         3360     13636     2.0           0     0
# 16721         4       2.25         3133     16197     2.0           0     0
# 11179         4       1.50         1380      7800     1.0           0     0
#
# ...

# %%
X_test
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 17465         4       2.50         2620     19864     2.0           0     0
# 8151          3       2.50         1960      7200     1.0           0     0
# 4892          2       1.75         3490     88909     1.0           0     3
# 966           3       1.00         1320      9000     1.0           0     0
# 2955          3       1.00         1080      5250     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 17566         5       3.00         3480     15185     2.0           0     0
# 10831         3       2.75         3176     13391     2.0           0     3
# 9066          4       2.50         3320     38043     2.0           0     0
# 3330          3       2.25         1440      9806     1.0           0     0
# 4851          5       3.25         4115      7910     2.0           0     0
#
# ...

# %%
y_train
# Out:
# 20102    594491.0
# 2735     535000.0
# 11469    451000.0
# 477      438924.0
# 4366     453000.0
#            ...
# 16059    530000.0
# 2798     310000.0
# 11531    765000.0
# 16721    685000.0
# 11179    477000.0
# Name: price, Length: 16209, dtype: float64

# %%
y_test
# Out:
# 17465    650000.0
# 8151     635000.0
# 4892     952000.0
# 966      196500.0
# 2955     329500.0
#            ...
# 17566    970000.0
# 10831    819000.0
# 9066     685000.0
# 3330     253000.0
# 4851     988830.0
# Name: price, Length: 5404, dtype: float64

# %%
scaler=StandardScaler()

# %%
scaled_data=scaler.fit_transform(X_train)

# %%
scaled_test_data=scaler.transform(X_test)

# %%
scaled_test_data[0]
# Out:
# array([ 0.68970711,  0.50024187,  0.58991592,  0.11626998,  0.93226802,
#        -0.08599941, -0.30438997,  0.90133192,  0.29016367,  0.99815314,
#        -0.65958107,  0.44276457, -0.20941177, -0.48185632,  1.01776377,
#         0.65416391,  0.74508996,  0.0218339 ])

# %%
from sklearn.svm import SVR

model=SVR()

model.fit(scaled_data,y_train)
# Out:
# SVR()

# %%
pred=model.predict(scaled_test_data)

# %%
pred
# Out:
# array([452258.36341702, 451094.9819624 , 451909.29327692, ...,
#        452675.09794955, 449955.30148759, 452596.72757255])

# %%
y_test
# Out:
# 17465    650000.0
# 8151     635000.0
# 4892     952000.0
# 966      196500.0
# 2955     329500.0
#            ...
# 17566    970000.0
# 10831    819000.0
# 9066     685000.0
# 3330     253000.0
# 4851     988830.0
# Name: price, Length: 5404, dtype: float64

# %%
model.predict([[-0.39232295, -0.79457496, -0.63188034, -0.07859531, -0.91767589,
       -0.08636268, -0.30323606,  0.90962588, -0.55930493, -0.35171583,
       -0.65644691, -0.03658169, -0.20893008, -0.61340088, -0.67814149,
        3.25524916, -0.69249512,  0.03459714]])
# Out:
# array([450708.40133422])

# %%
### grid/random

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,pred)
# Out:
# -0.048236865912391735
